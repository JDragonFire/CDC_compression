# %% [markdown]
# <a href="https://colab.research.google.com/github/JDragonFire/CDC_compression/blob/main/LossyCompression_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/buggyyang/CDC_compression.git
# Out:
# Cloning into 'CDC_compression'...
# remote: Enumerating objects: 359, done.
# remote: Counting objects: 100% (359/359), done.
# remote: Compressing objects: 100% (272/272), done.
# remote: Total 359 (delta 156), reused 279 (delta 82), pack-reused 0 (from 0)
# Receiving objects: 100% (359/359), 3.23 MiB | 18.78 MiB/s, done.
# Resolving deltas: 100% (156/156), done.
# Updating files: 100% (286/286), done.

# %%
# %cd CDC_compression/
# Out:
# /content/drive/MyDrive/CDC_compression

# %%
# !git config --global user.email "sjy0748@gmail.com"
# !git config --global user.name "JDragonFire"

# %%
# !git add .

# %%
# !git commit -m "clone_CDCcompression"
# Out:
# [main 2eb71e7] clone_CDCcompression
#  3 files changed, 0 insertions(+), 0 deletions(-)
#  mode change 100755 => 100644 imgs/1.png
#  mode change 100755 => 100644 imgs/2.png
#  mode change 100755 => 100644 imgs/3.png

# %%
# !ls
# Out:
# environment.yml  epsilonparam  imgs  LICENSE  README.md  xparam

# %%
# !pip install condacolab

# %%
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda env create -f environment.yml
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# pytorch-2.0.0        | 1.41 GB   | :   0% 0/1 [00:00<?, ?it/s]
# libcublas-11.11.3.6  | 364.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# libcusparse-11.7.5.8 | 176.3 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libnpp-11.8.0.86     | 147.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# mkl-2021.4.0         | 142.6 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# torchtriton-2.0.0    | 62.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# qt-main-5.15.2       | 53.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# !conda init
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.11/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
! activate exp_pytorch

# %%
# %cd ./epsilonparam/
# Out:
# /content/CDC_compression/epsilonparam

# %%
# !pip install lpips
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 160.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 67.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 27.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 99.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 56.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 52.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 21.5 MB/s eta 0:00:00
# ...

# %%
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 65.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 133.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.5
#     Uninstalling numpy-2.3.5:
#       Successfully uninstalled numpy-2.3.5
# ...

# %%
# !pip install einops

# %%
# !pip install tensorboard
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 90.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 126.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 110.5 MB/s eta 0:00:00
# ...

# %%
# !python train.py --device 0 --beta 0.1 --alpha 0.1
# Out:
# Traceback (most recent call last):
#   File "/content/CDC_compression/epsilonparam/train.py", line 108, in <module>
#     main()
#   File "/content/CDC_compression/epsilonparam/train.py", line 32, in main
#     train_data, val_data = load_data(
#                            ^^^^^^^^^^
#   File "/content/CDC_compression/epsilonparam/data/load_data.py", line 22, in load_data
#     train, val = load_dataset(data_config)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/CDC_compression/epsilonparam/data/load_dataset.py", line 21, in load_dataset
#     assert os.path.exists(data_path), "Data path {} not found.".format(data_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: Data path * not found.

# %%
# !python test_epsilonparam.py
# Out:
# usage: test_epsilonparam.py [-h] --ckpt CKPT [--gamma GAMMA]
#                             [--n_denoise_step N_DENOISE_STEP]
#                             [--device DEVICE] [--img_dir IMG_DIR]
#                             [--out_dir OUT_DIR] --lpips_weight LPIPS_WEIGHT
# test_epsilonparam.py: error: the following arguments are required: --ckpt, --lpips_weight
